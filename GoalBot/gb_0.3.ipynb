# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv(r'C:\Kenil Ramani\QB\GoalBot\CSV\v0.3.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128954 entries, 0 to 128953
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   invoiceDate      128954 non-null  object
#  1   quarter          128954 non-null  int64
#  2   month            128954 non-null  int64
#  3   year             128954 non-null  int64
#  4   day_of_week      128954 non-null  int64
#  5   day_of_month     128954 non-null  int64
#  6   day_of_year      128954 non-null  int64
#  7   week_of_year     128954 non-null  int64
#  8   salesDetails_id  128954 non-null  int64
#  9   billAmount       128954 non-null  int64
#  10  stockistId       102194 non-null  float64
#  11  chemistId        26760 non-null   float64
#  12  categoryId       21648 non-null   float64
#  13  hqId             118558 non-null  float64
#  14  regionId         118558 non-null  float64
#  15  cityId           115816 non-null  float64
#  16  qty              128954 non-null  int64
#  17  free             128954 non-null  int64
#  18  rate             128954 non-null  float64
#  19  amount           128954 non-null  float64
#  20  productId        128953 non-null  float64
#  21  divisionId       128953 non-null  float64
#  22  packingTypeId    128953 non-null  float64
#  23  mrp              128953 non-null  float64
# dtypes: float64(12), int64(11), object(1)
# memory usage: 23.6+ MB

# %%
df.columns
# Out:
# Index(['invoiceDate', 'quarter', 'month', 'year', 'day_of_week',
#        'day_of_month', 'day_of_year', 'week_of_year', 'salesDetails_id',
#        'billAmount', 'stockistId', 'chemistId', 'categoryId', 'hqId',
#        'regionId', 'cityId', 'qty', 'free', 'rate', 'amount', 'productId',
#        'divisionId', 'packingTypeId', 'mrp'],
#       dtype='object')

# %%
condition1 = df['stockistId'].notna() & df['chemistId'].isna()
condition2 = df['stockistId'].isna() & df['chemistId'].notna()
 
condition = condition1 | condition2
condition.sum()
# Out:
# np.int64(128954)

# %%
df.shape
# Out:
# (128954, 24)

# %%
day_mapping = {
        1: 'Sunday',
        2: 'Monday',
        3: 'Tuesday',
        4: 'Wednesday',
        5: 'Thursday',
        6: 'Friday',
        7: 'Saturday'
    }
 
df['day_of_week'] = df['day_of_week'].map(day_mapping)

# %%
df
# Out:
#        invoiceDate  quarter  month  year day_of_week  day_of_month  \
# 0         1/1/2021        1      1  2021      Friday             1
# 1         1/1/2021        1      1  2021      Friday             1
# 2         1/1/2021        1      1  2021      Friday             1
# 3         1/1/2021        1      1  2021      Friday             1
# 4         1/1/2021        1      1  2021      Friday             1
# ...            ...      ...    ...   ...         ...           ...
# 128949   1/20/2025        1      1  2025      Monday            20
# 128950   1/20/2025        1      1  2025      Monday            20
# 128951   1/20/2025        1      1  2025      Monday            20
# 128952   1/20/2025        1      1  2025      Monday            20
# 128953   1/20/2025        1      1  2025      Monday            20
#
#         day_of_year  week_of_year  salesDetails_id  billAmount  ...  regionId  \
# 0                 1             1            39119         457  ...       9.0
# 1                 1             1            39090        4277  ...       1.0
# 2                 1             1            39070        4530  ...       1.0
# 3                 1             1            39436        3240  ...       1.0
# 4                 1             1            39328       35465  ...       1.0
# ...             ...           ...              ...         ...  ...       ...
# 128949           20             4           141868       66775  ...       NaN
# 128950           20             4           141920       77314  ...       1.0
# 128951           20             4           141924       77314  ...       1.0
# 128952           20             4           141931       77314  ...       1.0
# 128953           20             4           141935       77314  ...       1.0
#
#         cityId  qty  free    rate   amount  productId  divisionId  \
# 0        582.0    6     0   68.06   408.36       26.0         1.0
# 1         47.0   20     0   67.89  1357.80    17249.0         3.0
# 2         22.0   30     0   50.91  1527.30      248.0         3.0
# 3        402.0   20     0   57.86  1157.20      195.0         1.0
# 4         21.0    0   300   38.19     0.00      231.0         3.0
# ...        ...  ...   ...     ...      ...        ...         ...
# 128949    22.0   10     0   54.96   549.60      248.0         3.0
# 128950    15.0   20     0   69.43  1388.60      245.0         3.0
# 128951    15.0   20     0   63.64  1272.80    17232.0         3.0
# 128952    15.0   20     0   86.78  1735.60        1.0         3.0
# 128953    15.0   20     0  138.85  2777.00       26.0         1.0
#
#         packingTypeId    mrp
# 0                38.0  216.0
# 1                28.0   99.0
# 2                28.0   79.2
# 3                42.0  180.0
# 4                28.0   69.3
# ...               ...    ...
# 128949           28.0   79.2
# 128950           28.0  108.0
# 128951           28.0   99.0
# 128952           28.0  135.0
# 128953           38.0  216.0
#
# [128954 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# invoiceDate             0
# quarter                 0
# month                   0
# year                    0
# day_of_week             0
# day_of_month            0
# day_of_year             0
# week_of_year            0
# salesDetails_id         0
# billAmount              0
# stockistId          26760
# chemistId          102194
# categoryId         107306
# hqId                10396
# regionId            10396
# cityId              13138
# qty                     0
# free                    0
# rate                    0
# amount                  0
# productId               1
# divisionId              1
# packingTypeId           1
# mrp                     1
# dtype: int64

# %%
df['chemistId'].unique()
# Out:
# array([ 1779.,    nan,  5676.,  5225.,  5454.,  2178.,  2934.,  5224.,
#          789.,   817.,  5363.,   795.,   732.,  5432.,  5236.,  2077.,
#         5473.,  5784.,  4126.,  2964.,  1626.,  5694.,  2328.,  4398.,
#          850.,  5445.,  1745.,  8830.,  5448.,  1839.,  6403.,  1758.,
#         5483.,   836.,  9747.,  3343.,  8079.,   802.,   675.,   992.,
#         2928.,  1272.,   681.,  5722.,  5243.,  2758.,  5412.,  1721.,
#         3421.,  1308.,  5476.,  7432.,  2606.,   756.,  5411.,  7984.,
