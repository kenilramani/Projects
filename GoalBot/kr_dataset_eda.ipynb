# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Kenil Ramani\QB\GoalBot\CSV\dataset_v4.05.csv')

# %%
# df.drop(['day_of_week', 'day_of_month', 'day_of_year', 'week_of_year', 'quarter', 'contents', 'month', 'year'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['salesId', 'invoiceId', 'invoiceDate', 'stockistId', 'chemistId',
#        'billAmount', 'salesDetails_Id', 'productCode', 'productName',
#        'productId', 'mrp', 'rate', 'batch', 'expiryDate', 'qty', 'free',
#        'amount', 'cashDiscountPercentage', 'productDiscountPercentage',
#        'productDiscount', 'extraSchemePercentage', 'extraScheme',
#        'taxableAmount', 'sgst', 'sgstAmount', 'cgst', 'cgstAmount', 'cess',
#        'cessAmount', 'ptr', 'pts', 'hsn', 'contents', 'packingTypeId',
#        'divisionId', 'cityId', 'regionId', 'customerName', 'addressId', 'hqId',
#        'categoryId', 'chemistTypeId'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# salesId                           0
# invoiceId                         0
# invoiceDate                       0
# stockistId                    25725
# chemistId                    100720
# billAmount                        0
# salesDetails_Id                   0
# productCode                       0
# productName                       0
# productId                         0
# mrp                               0
# rate                              0
# batch                             0
# expiryDate                        0
# qty                               0
# free                              0
# amount                            0
# cashDiscountPercentage            0
# productDiscountPercentage         0
# productDiscount                   0
# extraSchemePercentage             0
# extraScheme                       0
# taxableAmount                     0
# sgst                              0
# sgstAmount                        0
# cgst                              0
# ...

# %%
df['stockistId'] = df['stockistId'].round().astype('Int64')    # does not give error due to Int
df['chemistId'] = df['chemistId'].round().astype('Int64')    # does not give error due to Int

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126445 entries, 0 to 126444
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   salesId                    126445 non-null  int64
#  1   invoiceId                  126445 non-null  object
#  2   invoiceDate                126445 non-null  object
#  3   stockistId                 100720 non-null  Int64
#  4   chemistId                  25725 non-null   Int64
#  5   billAmount                 126445 non-null  int64
#  6   salesDetails_Id            126445 non-null  int64
#  7   productCode                126445 non-null  object
#  8   productName                126445 non-null  object
#  9   productId                  126445 non-null  int64
#  10  mrp                        126445 non-null  float64
#  11  rate                       126445 non-null  float64
#  12  batch                      126445 non-null  object
# ...

# %%
df.shape
# Out:
# (126445, 42)

# %%
df
# Out:
#         salesId  invoiceId invoiceDate  stockistId  chemistId  billAmount  \
# 0           193  DB-T-1052   7/14/2021        <NA>       1758      124604
# 1           631  DB-T-1179   7/26/2021        <NA>       1758      213574
# 2           304  DB-T-1084   6/29/2022        <NA>       1758       75218
# 3          1388  DB-T-1394   7/25/2022        <NA>       1758      151206
# 4          2543  DB-T-1726   9/14/2021        <NA>       1758      201934
# ...         ...        ...         ...         ...        ...         ...
# 126440    56847  DB-T-4349   1/28/2025        <NA>       5469       13680
# 126441     9689  DB-T-3506  12/22/2023        <NA>       5046        9000
# 126442     9689  DB-T-3506  12/22/2023        <NA>       5046        9000
# 126443     6703  DB-T-2831  11/23/2022        <NA>       2425        1568
# 126444    44310   DB-T-588   5/15/2024         118       <NA>       31826
#
#         salesDetails_Id productCode  productName  productId  ...  \
# ...

# %%
df_filtered = df[df['productId'] == 166].copy()

# %%
df_filtered
# Out:
#        salesId  invoiceId invoiceDate  stockistId  chemistId  billAmount  \
# 0          193  DB-T-1052   7/14/2021        <NA>       1758      124604
# 1          631  DB-T-1179   7/26/2021        <NA>       1758      213574
# 2          304  DB-T-1084   6/29/2022        <NA>       1758       75218
# 3         1388  DB-T-1394   7/25/2022        <NA>       1758      151206
# 4         2543  DB-T-1726   9/14/2021        <NA>       1758      201934
# ...        ...        ...         ...         ...        ...         ...
# 4002     55901  DB-T-3954    1/3/2025        <NA>       5676       20832
# 4009     13340   DB-T-660   5/25/2022        <NA>       1065      350986
# 5240     14276   DB-T-927    7/3/2021        <NA>       1758      143560
# 5603     50785   DB-T-611   5/16/2024         129       <NA>        4060
# 11967     4922  DB-T-2407  10/13/2022        <NA>       6505        3672
#
#        salesDetails_Id productCode productName  productId  ...  \
# ...

# %%
agg_df = df.groupby('productId').agg(
    invoice_count=('invoiceDate', 'count'),
    total_qty=('qty', 'sum'),
    total_amount=('amount', 'sum'),
    total_billAmount=('billAmount', 'sum')
).reset_index()

# Optional: Sort by invoice_count and pick top N to avoid overcrowding
top_n = 156
# agg_df = agg_df.sort_values('invoice_count', ascending=False).head(top_n)

# %%
agg_df
# Out:
#      productId  invoice_count  total_qty  total_amount  total_billAmount
# 0            1           1910     116535    8125711.71         162656499
# 1            2           1515      63598    5134329.73          94897319
# 2            8           2061     141851    6359431.85         157397715
# 3           11            300       3012     327943.03          22570380
# 4           12            106       1250     153282.41           5409390
# ..         ...            ...        ...           ...               ...
# 133      17615            127       4480     788927.60          32241811
# 134      17616             43       2201     784258.65           9038110
# 135      17617             40       1117     578134.18           7131905
# 136      17624              7        220      28144.60            868831
# 137      17625              2        105      28983.40             34920
#
# [138 rows x 5 columns]
